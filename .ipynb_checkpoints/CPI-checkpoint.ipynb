# %% [markdown]
# CPI dataは統計局のデータベースから取得。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
df_CPI = pd.read_excel('data/CPI Year AVG.xlsx', sheet_name = 'bn01-2 (2)', header=13, index_col=8)

# %%
df_CPI_all = df_CPI.iloc[:, 11]

# %%
series = df_CPI_all[1:]

# %%
df.index = df.index.str[:4]

# %%
series.index
# Out:
# Index(['1971年', '1972年', '1973年', '1974年', '1975年', '1976年', '1977年', '1978年',
#        '1979年', '1980年', '1981年', '1982年', '1983年', '1984年', '1985年', '1986年',
#        '1987年', '1988年', '1989年', '1990年', '1991年', '1992年', '1993年', '1994年',
#        '1995年', '1996年', '1997年', '1998年', '1999年', '2000年', '2001年', '2002年',
#        '2003年', '2004年', '2005年', '2006年', '2007年', '2008年', '2009年', '2010年',
#        '2011年', '2012年', '2013年', '2014年', '2015年', '2016年', '2017年', '2018年',
#        '2019年', '2020年', '2021年', '2022年', '2023年', '2024年'],
#       dtype='object', name='年月')

# %%
series.index = series.index.str[:4]

# %%
series.index
# Out:
# Index(['1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024'],
#       dtype='object', name='年月')

# %%
df_CPI_all.to_excel('result/df_CPI_all.xlsx')

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(series)
ax.set_ylabel("CPI")
ax.set_xlabel('Year')
plt.title('CPI')
plt.grid()
plt.savefig("CPI.png")
